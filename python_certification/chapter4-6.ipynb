# %% [markdown]
# chaapter4
#
# 1.B
# 正解：B
#
# 2.A 短絡演算子
# 正解：A
#
# 3.C?
# 正解：C
# if value == None は不完全？
#
# 4.D
# 正解：D
#
# 5.C 終端は
# 正解：C
#
# 6.A
# 正解：A
#
# 7.C?
# 正解：C
# items()メソッド　キーと値を取得
#
# 8.C? enumarate??
# 正解：C
# イテレータからインデックスと要素を取得
# iはインデックスのみ入る
#
# 9.D
# 正解：D
#
# 10.D? 文字列
# 正解：D

# %% [markdown]
# chapter5
#
# 1.C
# 正解：C
#
# 2.C
# 正解：C
#
# 3.A
# 正解：A
#
# 4.B
# 正解：Ｂ
#
# 5.C デフォルト引数
# 正解：C
#
# 6.D?  何もないときにデフォルトが参照される？
# 正解：D　デフォルト値が変更されていく
#
# 7.A?
# この書き方で関数が起動するの？
# 正解：A
#
# 8.C
# 正解：C
#
# 9.D?
# 正解：D
#
# 10.A??
# 不正解：B
# __doc__ でdocstrings

# %% [markdown]
# chapter6
#
# 1.C deque?
# 正解：C
#
# 2.D
# 正解：D
#
# 3.B
# 正解：B
#
# 4.D 追加はadd?
# 正解：D
#
# 5.A
# 正解：A
#
# 6.B
# 正解：B
#
# 7.B? タプルは使える？
# 不正解：C　　逆にリストなどのイテレータは辞書に使えない
#
# 8.A  []?
# 正解：A
#
# 9.D??
# 不正解：C
# 辞書にinclude()はない
# list(辞書)をすると　キーが要素になったリストが作られる
#
# 10.B?
# 正解：B
