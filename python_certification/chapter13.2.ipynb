# %% [markdown]
# chapter13
#
# 1.C
# 正解：C
#
# 2.B
# 正解：B
#
# 3.C
# 正解：C
#
# 4.D
# 正解：D
#
# 5.C
# 正解：C
#
# 6.D
# 正解：D
#
# 7.D
# 正解：D
#
# 8.D
# 正解：D
#
# 9.B
# 正解：B
#
# 10.C
# 正解：C
#
# 11.B
# 正解：B
#
# 12.B
# 正解：B
#
# 13.C
# 正解：C
#
# 14.D
# 正解：D
#
# 15.B
# 正解：B
#
# 16.B
# 正解：B
#
# 17.D
# 正解：D
#
# 18.C
# 正解：C
#
# 19.D
# 正解：D
#
# 20.B
# 正解：B

# %% [markdown]
# 21.B
# 正解：B
#
# 22.D
# 正解：D
#
# 23.A
# 正解：A
#
# 24.D
# 正解：D
#
# 25.B
# 正解：B
#
# 26.C
# 正解：C
#
# 27.B
# 正解：B
#
# 28.A
# 正解：A
#
# 29.C
# 正解：C
#
# 30.B
# B
#
# 31.A
# A
#
# 32.C
# C
#
# 33.C
# C
#
# 34.C?
# 正解：C
# findall()というメソッドは存在しない
#
# 35.D
# D
#
# 36.D
# D
#
# 37.B
# B
#
# 38.A
# A
#
# 39.A?
# 不正解：C
# 仮想環境のバージョンを変更しても、別の環境には影響しない
# アクティベートすると、プロンプトが変わる
#
# 40.B
# B
